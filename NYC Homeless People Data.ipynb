# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
NYCHomelessPeopleData = pd.read_csv('DHS_Daily_Report.csv')

# %%
NYCHomelessPeopleData.tail()
# Out:
#      Date of Census  Total Adults in Shelter  Total Children in Shelter  \
# 2388         5/7/20                    36932                      19760
# 2389         5/8/20                    37038                      19707
# 2390         5/9/20                    37061                      19710
# 2391        5/10/20                    37096                      19706
# 2392        5/11/20                    37099                      19700
#
#       Total Individuals in Shelter  Single Adult Men in Shelter  \
# 2388                         56692                        12711
# 2389                         56745                        12809
# 2390                         56771                        12800
# 2391                         56802                        12826
# 2392                         56799                        12810
#
#       Single Adult Women in Shelter  Total Single Adults in Shelter  \
# 2388                           4517                           17228
# ...

# %%
startOf2019 = 1897
dateIndex13to20 = [128,476,829, 1191, 1534,1897,2261]
dateIndex19to20 = [0,1987-startOf2019, 2077-startOf2019, 2169-startOf2019, 2261-startOf2019, 2352-startOf2019]

# %%
x = NYCHomelessPeopleData['Date of Census']
y = NYCHomelessPeopleData['Total Adults in Shelter']
plt.plot(x,y)
plt.xticks(fontsize=12)
plt.xticks(dateIndex13to20)
plt.title("Total Adults in NYC Homeless Shelters")
plt.xlabel("Date")
plt.ylabel("Number of Adults")
plt.show()

# %%
x = NYCHomelessPeopleData['Date of Census'][startOf2019:]
y = NYCHomelessPeopleData['Total Adults in Shelter'][startOf2019:]
plt.plot(x,y)
plt.xticks(fontsize=12)
plt.xticks(dateIndex19to20)
plt.title("Total Adults in NYC Homeless Shelters")
plt.xlabel("Date")
plt.ylabel("Number of Adults")
plt.show()

# %%
x = NYCHomelessPeopleData['Date of Census']
y = NYCHomelessPeopleData['Total Children in Shelter']
plt.plot(x,y)
plt.xticks(fontsize=12)
plt.xticks(dateIndex13to20)
plt.title("Total Children in NYC Homeless Shelters")
plt.xlabel("Date")
plt.ylabel("Number of Children")
plt.show()

# %%
x = NYCHomelessPeopleData['Date of Census'][startOf2019:]
y = NYCHomelessPeopleData['Total Children in Shelter'][startOf2019:]
plt.plot(x,y)
plt.xticks(fontsize=12)
plt.xticks(dateIndex19to20)
plt.title("Total Children in NYC Homeless Shelters")
plt.xlabel("Date")
plt.ylabel("Number of Adults")
plt.show()

# %%
x = NYCHomelessPeopleData['Date of Census']
y = NYCHomelessPeopleData['Total Individuals in Shelter']
plt.plot(x,y)
plt.xticks(fontsize=12)
plt.xticks(dateIndex13to20)
plt.title("Total Individuals in NYC Homeless Shelters")
plt.xlabel("Date")
plt.ylabel("Number of Individuals")
plt.show()

# %%
x = NYCHomelessPeopleData['Date of Census'][startOf2019:]
y = NYCHomelessPeopleData['Total Individuals in Shelter'][startOf2019:]
plt.plot(x,y)
plt.xticks(fontsize=12)
plt.xticks(dateIndex19to20)
plt.title("Total Individuals in NYC Homeless Shelters")
plt.xlabel("Date")
plt.ylabel("Number of Individuals")
plt.show()

#GOOD ONE

# %%
x = NYCHomelessPeopleData['Date of Census']
y = NYCHomelessPeopleData['Single Adult Men in Shelter']
plt.plot(x,y)
plt.xticks(fontsize=12)
plt.xticks(dateIndex13to20)
plt.title("Single Adult Men in NYC Homeless Shelters")
plt.xlabel("Date")
plt.ylabel("Number of Single Adult Men")
plt.show()

# %%
x = NYCHomelessPeopleData['Date of Census'][startOf2019:]
y = NYCHomelessPeopleData['Single Adult Men in Shelter'][startOf2019:]
plt.plot(x,y)
plt.xticks(fontsize=12)
plt.xticks(dateIndex19to20)
plt.title("Single Adult Men in NYC Homeless Shelters")
plt.xlabel("Date")
plt.ylabel("Number of Single Adult Men")
plt.show()

# %%
x = NYCHomelessPeopleData['Date of Census']
y = NYCHomelessPeopleData['Single Adult Women in Shelter']
plt.plot(x,y)
plt.xticks(fontsize=12)
plt.xticks(dateIndex13to20)
plt.title("Single Adult Women in NYC Homeless Shelters")
plt.xlabel("Date")
plt.ylabel("Number of Single Adult Women")
plt.show()

# %%
x = NYCHomelessPeopleData['Date of Census'][startOf2019:]
y = NYCHomelessPeopleData['Single Adult Women in Shelter'][startOf2019:]
plt.plot(x,y)
plt.xticks(fontsize=12)
plt.xticks(dateIndex19to20)
plt.title("Single Adult Women in NYC Homeless Shelters")
plt.xlabel("Date")
plt.ylabel("Number of Single Adult Women")
plt.show()

# %%
x = NYCHomelessPeopleData['Date of Census']
y = NYCHomelessPeopleData['Total Single Adults in Shelter']
plt.plot(x,y)
plt.xticks(fontsize=12)
plt.xticks(dateIndex13to20)
plt.title("Total Single Adults in NYC Homeless Shelters")
plt.xlabel("Date")
plt.ylabel("Number of Single Adults")
plt.show()

# %%
x = NYCHomelessPeopleData['Date of Census'][startOf2019:]
y = NYCHomelessPeopleData['Total Single Adults in Shelter'][startOf2019:]
plt.plot(x,y)
plt.xticks(fontsize=12)
plt.xticks(dateIndex19to20)
plt.title("Total Single Adults in NYC Homeless Shelters")
plt.xlabel("Date")
plt.ylabel("Number of Single Adults")
plt.show()

# %%
x = NYCHomelessPeopleData['Date of Census']
y = NYCHomelessPeopleData['Families with Children in Shelter']
plt.plot(x,y)
plt.xticks(fontsize=12)
plt.xticks(dateIndex13to20)
plt.title("Families with Children in Shelter in NYC Homeless Shelters")
plt.xlabel("Date")
plt.ylabel("Families with Children in Shelter")
plt.show()

# %%
x = NYCHomelessPeopleData['Date of Census'][startOf2019:]
y = NYCHomelessPeopleData['Families with Children in Shelter'][startOf2019:]
plt.plot(x,y)
plt.xticks(fontsize=12)
plt.xticks(dateIndex19to20)
plt.title("Families with Children in NYC Homeless Shelters")
plt.xlabel("Date")
plt.ylabel("Number of Families with Children in Shelter")
plt.show()

# %%
x = NYCHomelessPeopleData['Date of Census']
y = NYCHomelessPeopleData['Adults in Families with Children in Shelter']
plt.plot(x,y)
plt.xticks(fontsize=12)
plt.xticks(dateIndex13to20)
plt.title("Adults in Families with Children in NYC Homeless Shelters")
plt.xlabel("Date")
plt.ylabel("Number of Adults in Families with Children")
plt.show()

# %%
x = NYCHomelessPeopleData['Date of Census'][startOf2019:]
y = NYCHomelessPeopleData['Adults in Families with Children in Shelter'][startOf2019:]
plt.plot(x,y)
plt.xticks(fontsize=12)
plt.xticks(dateIndex19to20)
plt.title("Adults in Families with Children in NYC Homeless Shelters")
plt.xlabel("Date")
plt.ylabel("Number of Adults in Families with Children in Shelter")
plt.show()

# %%
x = NYCHomelessPeopleData['Date of Census']
y = NYCHomelessPeopleData['Children in Families with Children in Shelter']
plt.plot(x,y)
plt.xticks(fontsize=12)
plt.xticks(dateIndex13to20)
plt.title("Children in Families with Children in NYC Homeless Shelters")
plt.xlabel("Date")
plt.ylabel("Number of Children in Families with Children")
plt.show()

# %%
x = NYCHomelessPeopleData['Date of Census'][startOf2019:]
y = NYCHomelessPeopleData['Children in Families with Children in Shelter'][startOf2019:]
plt.plot(x,y)
plt.xticks(fontsize=12)
plt.xticks(dateIndex19to20)
plt.title("Total Children in Families with Children in NYC Homeless Shelters")
plt.xlabel("Date")
plt.ylabel("Number of Children in Families with Children in Shelter")
plt.show()

# %%
x = NYCHomelessPeopleData['Date of Census']
y = NYCHomelessPeopleData["Total Individuals in Families with Children in Shelter"] 
plt.plot(x,y)
plt.xticks(fontsize=12)
plt.xticks(dateIndex13to20)
plt.title("Total Individuals in Families with Children in NYC Homeless Shelters")
plt.xlabel("Date")
plt.ylabel("Total Individuals in Families with Children")
plt.show()

# %%
x = NYCHomelessPeopleData['Date of Census'][startOf2019:]
y = NYCHomelessPeopleData['Total Individuals in Families with Children in Shelter'][startOf2019:]
plt.plot(x,y)
plt.xticks(fontsize=12)
plt.xticks(dateIndex19to20)
plt.title("Total Individuals in Families with Children in NYC Homeless Shelters")
plt.xlabel("Date")
plt.ylabel("Number of Individuals ini Families with Children in Shelter")
plt.show()

# %%
x = NYCHomelessPeopleData['Date of Census']
y = NYCHomelessPeopleData['Adult Families in Shelter']
plt.plot(x,y)
plt.xticks(fontsize=12)
plt.xticks(dateIndex13to20)
plt.title("Adult Families in NYC Homeless Shelters")
plt.xlabel("Date")
plt.ylabel("Number of Adult Families")
plt.show()

# %%
x = NYCHomelessPeopleData['Date of Census'][startOf2019:]
y = NYCHomelessPeopleData['Adult Families in Shelter'][startOf2019:]
plt.plot(x,y)
plt.xticks(fontsize=12)
plt.xticks(dateIndex19to20)
plt.title("Total Adult Families in NYC Homeless Shelters")
plt.xlabel("Date")
plt.ylabel("Number of Adult Families in Shelter")
plt.show()

# %%
x = NYCHomelessPeopleData['Date of Census']
y = NYCHomelessPeopleData['Individuals in Adult Families in Shelter']
plt.plot(x,y)
plt.xticks(fontsize=12)
plt.xticks(dateIndex13to20)
plt.title("Individuals in Adult Families in NYC Homeless Shelters")
plt.xlabel("Date")
plt.ylabel("Number of Inidivuals in Adult Families")
plt.show()

# %%
x = NYCHomelessPeopleData['Date of Census'][startOf2019:]
y = NYCHomelessPeopleData['Individuals in Adult Families in Shelter'][startOf2019:]
plt.plot(x,y)
plt.xticks(fontsize=12)
plt.xticks(dateIndex19to20)
plt.title("Total Individuals in Adult Families in Shelter in NYC Homeless Shelters")
plt.xlabel("Date")
plt.ylabel("Number of Individuals in Adult Families in Shelter")
plt.show()
